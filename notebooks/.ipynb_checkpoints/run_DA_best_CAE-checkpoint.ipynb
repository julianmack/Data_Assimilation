# %%
import os
import sys
import utils
from matplotlib import pyplot as plt
# %matplotlib inline

#import pipeline
parent_dir = os.path.abspath(os.path.join(os.getcwd(), os.pardir))
sys.path.append(parent_dir) #to import pipeline
import pipeline

# %% [markdown]
# ## Get best model

# %%
###CHANGE THIS FILE TO THE SUBDIRECTORY OF INTEREST:
exp_dir_base = "/data/home/jfm1118/DA/experiments"
##############

results = utils.extract_res_from_files(exp_dir_base)
df_res = utils.create_res_df(results, True)


#get best model(s)
nmodels = 6

best = df_res.loc[df_res["valid_loss"].nsmallest(nmodels).index]
paths = list(best.path.values)

#plot traing:
res_best = utils.extract_res_from_files(paths)
utils.plot_results_loss_epochs(res_best)

best
# Out:
# 70 experiments conducted
# 6 experiments conducted
# (2, 3)
#     model    valid_loss activation latent_dims num_layers total_channels  \
# 52   CAE5  18540.800167      lrelu          36          6             45
# 43   CAE6  18792.643163      lrelu          36          6             45
# 55   CAE6  18846.080346      lrelu          72          6             49
# 49  CAE1A  20236.214546      lrelu          72          6             49
# 58   CAE6  20743.870281      lrelu          18          6             41
# 50  CAE1A  20999.556670      lrelu          72          8             65
#
#     channels/layer  batch_norm                     channels  conv_changeover  \
# 52        7.500000         0.0        [1, 8, 8, 8, 8, 8, 4]              1.0
# 43        7.500000         0.0        [1, 8, 8, 8, 8, 8, 4]              1.0
# 55        8.166667         0.0        [1, 8, 8, 8, 8, 8, 8]              1.0
# 49        8.166667         0.0        [1, 8, 8, 8, 8, 8, 8]              1.0
# 58        6.833333         0.0       [1, 2, 4, 8, 16, 8, 2]              0.0
# 50        8.125000         0.0  [1, 8, 8, 8, 8, 8, 8, 8, 8]              5.0
#
#     first_channel learning_rate  \
# 52            8.0            ??
# 43            8.0            ??
# 55            8.0            ??
# 49            8.0            ??
# 58            2.0         0.001
# 50            8.0            ??
#
#                                                  path
# 52      /data/home/jfm1118/DA/experiments/CAE_zoo2/17
# 43      /data/home/jfm1118/DA/experiments/CAE_zoo2/13
# 55      /data/home/jfm1118/DA/experiments/CAE_zoo2/12
# 49       /data/home/jfm1118/DA/experiments/CAE_zoo2/0
# 58  /data/home/jfm1118/DA/experiments/CAE_zooBN/CA...
# 50      /data/home/jfm1118/DA/experiments/CAE_zoo2/36

# %%
## best model is top middle (?) (final model). Index = 1
idx = 1 ##UPDATE THIS
fp_base = res_best[idx]["path"]
print(os.listdir(fp_base))
model_fp = fp_base + "/24.pth" ##UPDATE THIS
settings = res_best[idx]["settings"]
# Out:
# ['24.pth', 'test.csv', '20.pth', 'train.csv', '15.pth', '0.pth', '10.pth', 'settings.txt', '5.pth']

# %% [markdown]
# ### Perform DA

# %%
from pipeline import DAPipeline

settings.OBS_FRAC = 0.01  #1 % of observations
settings.OBS_VARIANCE = 0.01
settings.AE_MODEL_FP = model_fp
da = DAPipeline(settings)
w_opt = da.Var_DA_routine(settings)
# Out:
# (2475, 247520)
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-53017bbb2af0> in <module>()
#       5 settings.AE_MODEL_FP = model_fp
#       6 da = DAPipeline(settings)
# ----> 7 w_opt = da.Var_DA_routine(settings)
#
# /data/home/jfm1118/DA/pipeline/DataAssimilation.py in Var_DA_routine(self, settings, return_stats)
#      31         u_c = self.data.get("u_c")
#      32
# ---> 33         self.init_VarDA()
#      34
#      35         w_0 = self.data.get("w_0")
#
# /data/home/jfm1118/DA/pipeline/DataAssimilation.py in init_VarDA(self)
#     165             kwargs = settings.get_kwargs()
#     166
# --> 167             encoder, decoder = utils.ML_utils.load_AE(settings.AE_MODEL_TYPE, settings.AE_MODEL_FP, **kwargs)
#     168
#     169             V_trunc = decoder
#
# /data/home/jfm1118/DA/pipeline/utils.py in load_AE(ModelClass, path, **kwargs)
#     329         """Loads an encoder and decoder"""
#     330         model = ModelClass(**kwargs)
# --> 331         model.load_state_dict(torch.load(path))
#     332         #model.eval()
#     333         encoder = model.encode
#
# /data/anaconda/envs/py35/lib/python3.5/site-packages/torch/serialization.py in load(f, map_location, pickle_module)
#     364             (sys.version_info[0] == 3 and isinstance(f, pathlib.Path)):
#     365         new_fd = True
# --> 366         f = open(f, 'rb')
#     367     try:
#     368         return _load(f, map_location, pickle_module)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/data/home/jfm1118/DA/experiments/CAE_zoo2/1324.pth'
